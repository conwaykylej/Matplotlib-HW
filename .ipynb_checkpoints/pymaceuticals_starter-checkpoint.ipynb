# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# - The heavier mice had correspondingly heavier tumors as is seen in the scatter plot
#
# - Capomulin and Ramicane had the most consistent results across all statistics as can be seen by their sem and the lowest standard deviation of all of the drugs.
#
# - Similarly, Capomulin and Ramicane showed the most timepoints for all of the drugs, indicating their mice lasted longest in the various treatments.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem

# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_mouse_df = pd.merge(mouse_metadata, study_results, how='left', on='Mouse ID')

# Display the data table for preview

combined_mouse_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
len(combined_mouse_df["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_ids = combined_mouse_df.loc[combined_mouse_df.duplicated(
    subset=['Mouse ID', 'Timepoint'], keep=False)]

# %%
duplicate_ids.head()
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_data = combined_mouse_df.loc[combined_mouse_df['Mouse ID'] == "g989"]
dup_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

cleaned_df = combined_mouse_df.loc[combined_mouse_df['Mouse ID'] != "g989"]
cleaned_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
len(cleaned_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mean_df = cleaned_df.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
median_df = cleaned_df.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
var_df = cleaned_df.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
stdev_df = cleaned_df.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
sem_df = cleaned_df.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

summary_df = pd.DataFrame({'Mean of Tumor Volume': mean_df,
             'Median of Tumor Volume': median_df,
             'Variance of Tumor Volume': var_df,
             'Standard Deviaiton of Tumor Volume': stdev_df,
             'Standard Error Mean of Tumor Volume': sem_df})

summary_df.round(2)
# Out:
#               Mean of Tumor Volume  Median of Tumor Volume  \
# Drug Regimen
# Capomulin                    40.68                   41.56
# Ceftamin                     52.59                   51.78
# Infubinol                    52.88                   51.82
# Ketapril                     55.24                   53.70
# Naftisol                     54.33                   52.51
# Placebo                      54.03                   52.29
# Propriva                     52.32                   50.45
# Ramicane                     40.22                   40.67
# Stelasyn                     54.23                   52.43
# Zoniferol                    53.24                   51.82
#
#               Variance of Tumor Volume  Standard Deviaiton of Tumor Volume  \
# Drug Regimen
# Capomulin                        24.95                                4.99
# Ceftamin                         39.29                                6.27
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

summary_table = cleaned_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean","median","var","std","sem"]})
summary_table.round(2)
# Out:
#              Tumor Volume (mm3)
#                            mean median    var   std   sem
# Drug Regimen
# Capomulin                 40.68  41.56  24.95  4.99  0.33
# Ceftamin                  52.59  51.78  39.29  6.27  0.47
# Infubinol                 52.88  51.82  43.13  6.57  0.49
# Ketapril                  55.24  53.70  68.55  8.28  0.60
# Naftisol                  54.33  52.51  66.17  8.13  0.60
# Placebo                   54.03  52.29  61.17  7.82  0.58
# Propriva                  52.32  50.45  43.85  6.62  0.54
# Ramicane                  40.22  40.67  23.49  4.85  0.32
# Stelasyn                  54.23  52.43  59.45  7.71  0.57
# Zoniferol                 53.24  51.82  48.53  6.97  0.52

# %%
drugs_sorted = pd.DataFrame(cleaned_df["Drug Regimen"]).value_counts()
drugs_sorted.head()
# Out:
# Drug Regimen
# Capomulin       230
# Ramicane        228
# Ketapril        188
# Naftisol        186
# Zoniferol       182
# dtype: int64

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

drugs_sorted = pd.DataFrame(pd.value_counts(cleaned_df["Drug Regimen"]))
drugs_sorted.head()
drugs_sorted.plot(kind="bar")
plt.title("Timepoints per Drug Regimen")
plt.ylabel("Number of Mice per Time Point")
plt.xlabel("Drug Regimen")
plt.show()
plt.tight_layout()

# Count how many times each maker appears in our group

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

x_axis = cleaned_df["Drug Regimen"].value_counts().index
y_axis = cleaned_df["Drug Regimen"].value_counts()
plt.bar(x_axis, y_axis, color="b", align="center", width=.6)
plt.xticks(x_axis, rotation=90)
plt.title("Timepoints per Drug Regimen")
plt.ylabel("Number of Mice per Time Point")
plt.xlabel("Drug Regimen")
plt.show()
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_count = pd.value_counts(cleaned_df['Sex'])

gender_pie = gender_count.plot(kind='pie', y='sex', autopct='%1.1f%%')
gender_pie.set_ylabel("Sex")
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
plt.show()

# %%
cleaned_df['Sex'].value_counts()
# Out:
# Male      958
# Female    922
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
pops = [958, 922]
plt.pie(
    pops, 
    labels=["Male","Female"],          
    colors=["blue","pink"],
    autopct='%1.1f%%',
)
plt.axis("equal")

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
timepoint_df = pd.DataFrame(cleaned_df.groupby('Mouse ID')['Timepoint'].max().sort_values()).reset_index().rename(columns={'Timepoint': 'max_timepoint'})
timepoint_df

# Merge max timepoint onto data_df
merged_df = pd.merge(cleaned_df, timepoint_df, on='Mouse ID')
merged_df.head(10)
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
# 6     k403     Ramicane  Male          21          16         30
# 7     k403     Ramicane  Male          21          16         35
# 8     k403     Ramicane  Male          21          16         40
# 9     k403     Ramicane  Male          21          16         45
#
#    Tumor Volume (mm3)  Metastatic Sites  max_timepoint
# 0           45.000000                 0             45
# 1           38.825898                 0             45
# 2           35.014271                 1             45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
drugs = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
drug_values = []

# locate each drug in the orginal dataframe
for drug in drugs:
    
    temp_df = merged_df.loc[merged_df['Drug Regimen'] == drug]

    #narrow down to rows only containing the final timepoint for each regimen
    final_volume_df = temp_df.loc[temp_df['Timepoint'] == temp_df['max_timepoint']]
    
    # collect final volume values for each regimen
    values = final_volume_df['Tumor Volume (mm3)']
    drug_values.append(values)
    
    # calculate the IQR for each regimen
    quartiles = values.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'IQR for {drug}: {iqr}')
    
    # find upper and lower bounds to help identify outliers for each regimen
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'Lower Bound for {drug}: {lower_bound}')
    print(f'Upper Bound for {drug}: {upper_bound}')
    
    # check for outliers
    outliers_count = (values.loc[(final_volume_df['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (final_volume_df['Tumor Volume (mm3)'] <= lower_bound)]).count()
    print(f'Number of {drug} outliers: {outliers_count}')
# Out:
# IQR for Capomulin: 7.781863460000004
# Lower Bound for Capomulin: 20.70456164999999
# Upper Bound for Capomulin: 51.83201549
# Number of Capomulin outliers: 0
# IQR for Ramicane: 9.098536719999998
# Lower Bound for Ramicane: 17.912664470000003
# Upper Bound for Ramicane: 54.30681135
# Number of Ramicane outliers: 0
# IQR for Infubinol: 11.477135160000003
# Lower Bound for Infubinol: 36.83290494999999
# Upper Bound for Infubinol: 82.74144559000001
# Number of Infubinol outliers: 1
# IQR for Ceftamin: 15.577752179999997
# Lower Bound for Ceftamin: 25.355449580000002
# Upper Bound for Ceftamin: 87.66645829999999
# Number of Ceftamin outliers: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

plt.boxplot(drug_values)

plt.title('Final Tumor Volume by Drug')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

x_axis =cleaned_df.loc[cleaned_df["Mouse ID"]== "s185"]
x_axis = x_axis["Timepoint"]

y_axis =cleaned_df.loc[cleaned_df["Mouse ID"]== "s185"]
y_axis = y_axis["Tumor Volume (mm3)"]

plt.plot(x_axis, y_axis)
plt.title("Tumor Volume with Capomulin for Mouse s185")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_df = merged_df.loc[merged_df['Drug Regimen'] == 'Capomulin']

# Find average tumor volume for each mouse

avg_vol_df = pd.DataFrame(capomulin_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean().sort_values()).reset_index().rename(columns={'Tumor Volume (mm3)': 'avg_tumor_vol'})

# Merge average tumor volume
avg_vol_df = pd.merge(capomulin_df, avg_vol_df, on='Mouse ID')
final_avg_vol_df = avg_vol_df[['Weight (g)', 'avg_tumor_vol']].drop_duplicates()
final_avg_vol_df

x = final_avg_vol_df['Weight (g)']
y = final_avg_vol_df['avg_tumor_vol']

plt.scatter(x, y)

plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x = final_avg_vol_df['Weight (g)']
y = final_avg_vol_df['avg_tumor_vol']

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)

# Print the answer to above calculation
print(f"""The correlation between weight and average tumor volume
on the Capomulin regimen is {round(correlation[0],2)}.""")

# Calculate linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x,y)
plt.plot(x,regress_values,"r-")

# Annotate linear regression
plt.annotate(line_eq,(20,37),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')
plt.show()
# Out:
# The correlation between weight and average tumor volume
# on the Capomulin regimen is 0.84.
